# %%
import os
import json
import pandas as pd

CARPETA_BLOQUES = "bloques_detalles"
CSV_PRINCIPAL = "anuncios_unificados1.csv"

def cargar_bloques_detalles(carpeta):
    all_detalles = []
    for archivo in sorted(os.listdir(carpeta)):
        if archivo.endswith(".json"):
            ruta = os.path.join(carpeta, archivo)
            with open(ruta, "r", encoding="utf-8") as f:
                bloque = json.load(f)
                all_detalles.extend(bloque)
    return all_detalles

def unir_datos(csv_principal, carpeta_bloques):
    df_base = pd.read_csv(csv_principal)
    
    detalles = cargar_bloques_detalles(carpeta_bloques)
    
    df_detalles = pd.DataFrame(detalles)
    
    df_detalles["url"] = df_detalles["url"].astype(str)
    df_base["url"] = df_base["url"].astype(str)
    
    df_final = df_base.merge(df_detalles, on="url", how="left")
    
    
    return df_final

if __name__ == "__main__":
    df_completo = unir_datos(CSV_PRINCIPAL, CARPETA_BLOQUES)
    print(f"Total registros en dataframe final: {len(df_completo)}")
    print(df_completo.head(5))
    
    df_completo.to_csv("anuncios_completo.csv", index=False, encoding="utf-8")
# Out:
# Total registros en dataframe final: 99929
#                                        id_extraccion  \
# 0  https://www.autocasion.com/coches-segunda-mano...
# 1  https://www.autocasion.com/coches-segunda-mano...
# 2  https://www.autocasion.com/coches-segunda-mano...
# 3  https://www.autocasion.com/coches-segunda-mano...
# 4  https://www.autocasion.com/coches-segunda-mano...
#
#          timestamp_extraccion   marca  \
# 0  2025-06-20T21:10:20.086439  ABARTH
# 1  2025-06-20T21:10:20.086694  ABARTH
# 2  2025-06-20T21:10:20.086996  ABARTH
# 3  2025-06-20T21:10:20.087274  ABARTH
# 4  2025-06-20T21:10:20.087595  ABARTH
#
#                                               titulo  \
# 0     ABARTH 500 C 695C 1.4 16v T-Jet 132kW (180 CV)
# 1  ABARTH 124 SPIDER  Spider Turbo Multiair 125kW...
# 2                          ABARTH 595 1.4T JET 121KW
# 3            ABARTH 695 Pequeño  Manual de 3 Puertas
# 4                           ABARTH 500 1.4 Turbo 595
#
#                                                  url  \
# 0  https://www.autocasion.com/coches-segunda-mano...
# 1  https://www.autocasion.com/coches-segunda-mano...
# 2  https://www.autocasion.com/coches-segunda-mano...
# 3  https://www.autocasion.com/coches-segunda-mano...
# 4  https://www.autocasion.com/coches-segunda-mano...
#
#                                                 tags  \
# 0        ['2022', 'Gasolina', '23.213 km', 'Madrid']
# 1     ['2018', 'Gasolina', '97.814 km', 'Barcelona']
# 2        ['2022', 'Gasolina', '33.602 km', 'Málaga']
# 3  ['2018', 'Gasolina', '48.500 km', 'Islas Balea...
# 4     ['2020', 'Gasolina', '32.922 km', 'Barcelona']
#
#                                       detalles_ficha  \
# 0  [Matriculado: 12/2022, 23.213 km, Garantía: 12...
# 1  [Matriculado: 12/2018, 97.814 km, Garantía: 12...
# 2  [Matriculado: 03/2022, 33.602 km, Garantía: 12...
# 3  [Matriculado: 02/2018, 48.500 km, Garantía: 12...
# 4  [Matriculado: 07/2020, 32.922 km, Garantía: 12...
#
#                                              precios
# 0  [Precio al contado: 22.990 €, Precio financiad...
# 1  [Precio al contado: 23.990 €, Precio financiad...
# 2  [Precio al contado: 22.500 €, Precio financiad...
# 3                      [Precio al contado: 22.950 €]
# 4  [Precio al contado: 16.999 €, Precio financiad...

# %%
df_completo
# Out:
#                                            id_extraccion  \
# 0      https://www.autocasion.com/coches-segunda-mano...
# 1      https://www.autocasion.com/coches-segunda-mano...
# 2      https://www.autocasion.com/coches-segunda-mano...
# 3      https://www.autocasion.com/coches-segunda-mano...
# 4      https://www.autocasion.com/coches-segunda-mano...
# ...                                                  ...
# 99924  https://www.autocasion.com/coches-km0/km-0/yud...
# 99925  https://www.autocasion.com/coches-km0/km-0/yud...
# 99926  https://www.autocasion.com/coches-km0/km-0/yud...
# 99927  https://www.autocasion.com/coches-km0/km-0/yud...
# 99928  https://www.autocasion.com/coches-segunda-mano...
#
#              timestamp_extraccion     marca  \
# 0      2025-06-20T21:10:20.086439    ABARTH
# 1      2025-06-20T21:10:20.086694    ABARTH
# 2      2025-06-20T21:10:20.086996    ABARTH
# 3      2025-06-20T21:10:20.087274    ABARTH
# 4      2025-06-20T21:10:20.087595    ABARTH
# ...                           ...       ...
# 99924  2025-06-21T00:33:12.156646  YOOUDOOO
# 99925  2025-06-21T00:33:12.156777  YOOUDOOO
# 99926  2025-06-21T00:33:12.156928  YOOUDOOO
# 99927  2025-06-21T00:33:12.157050  YOOUDOOO
# 99928  2025-06-21T00:33:12.157210  YOOUDOOO
#
#                                                   titulo  \
# 0         ABARTH 500 C 695C 1.4 16v T-Jet 132kW (180 CV)
# 1      ABARTH 124 SPIDER  Spider Turbo Multiair 125kW...
# 2                              ABARTH 595 1.4T JET 121KW
# 3                ABARTH 695 Pequeño  Manual de 3 Puertas
# 4                               ABARTH 500 1.4 Turbo 595
# ...                                                  ...
# 99924                           YOOUDOOO Y2 1.5L Comfort
# 99925  YOOUDOOO K3 YUDO Pequeño  Automático de 5 Puertas
# 99926                                   YOOUDOOO K3 70kW
# 99927                                   YOOUDOOO K3 70kW
# 99928                                   YOOUDOOO K3 70kW
#
#                                                      url  \
# 0      https://www.autocasion.com/coches-segunda-mano...
# 1      https://www.autocasion.com/coches-segunda-mano...
# 2      https://www.autocasion.com/coches-segunda-mano...
# 3      https://www.autocasion.com/coches-segunda-mano...
# 4      https://www.autocasion.com/coches-segunda-mano...
# ...                                                  ...
# 99924  https://www.autocasion.com/coches-km0/km-0/yud...
# 99925  https://www.autocasion.com/coches-km0/km-0/yud...
# 99926  https://www.autocasion.com/coches-km0/km-0/yud...
# 99927  https://www.autocasion.com/coches-km0/km-0/yud...
# 99928  https://www.autocasion.com/coches-segunda-mano...
#
#                                                     tags  \
# 0            ['2022', 'Gasolina', '23.213 km', 'Madrid']
# 1         ['2018', 'Gasolina', '97.814 km', 'Barcelona']
# 2            ['2022', 'Gasolina', '33.602 km', 'Málaga']
# 3      ['2018', 'Gasolina', '48.500 km', 'Islas Balea...
# 4         ['2020', 'Gasolina', '32.922 km', 'Barcelona']
# ...                                                  ...
# 99924           ['2025', 'Gasolina', '2 km', 'La Rioja']
# 99925        ['2024', 'Eléctrico', '10 km', 'Barcelona']
# 99926       ['2024', 'Eléctrico', '3.000 km', 'Sevilla']
# 99927      ['2025', 'Eléctrico', '4.585 km', 'La Rioja']
# 99928       ['2024', 'Eléctrico', '14.066 km', 'Toledo']
#
#                                           detalles_ficha  \
# 0      [Matriculado: 12/2022, 23.213 km, Garantía: 12...
# 1      [Matriculado: 12/2018, 97.814 km, Garantía: 12...
# 2      [Matriculado: 03/2022, 33.602 km, Garantía: 12...
# 3      [Matriculado: 02/2018, 48.500 km, Garantía: 12...
# 4      [Matriculado: 07/2020, 32.922 km, Garantía: 12...
# ...                                                  ...
# 99924  [Matriculado: 02/2025, 2 km, Garantía: 36 mese...
# 99925  [Matriculado: 08/2024, 10 km, Garantía: 12 mes...
# 99926  [Matriculado: 07/2024, 3.000 km, Garantía: 96 ...
# 99927  [Matriculado: 01/2025, 4.585 km, Garantía: 84 ...
# 99928  [Matriculado: 06/2024, 14.066 km, Garantía: 12...
#
#                                                  precios
# 0      [Precio al contado: 22.990 €, Precio financiad...
# 1      [Precio al contado: 23.990 €, Precio financiad...
# 2      [Precio al contado: 22.500 €, Precio financiad...
# 3                          [Precio al contado: 22.950 €]
# 4      [Precio al contado: 16.999 €, Precio financiad...
# ...                                                  ...
# 99924  [Precio al contado: 17.590 €, Precio financiad...
# 99925  [Precio al contado: 26.838 €, Precio financiad...
# 99926  [Precio al contado: 21.900 €, Precio financiad...
# 99927  [Precio al contado: 22.990 €, Precio financiad...
# 99928  [Precio al contado: 21.950 €, Precio de venta ...
#
# [99929 rows x 8 columns]
